# %%
import pandas as pd
import numpy as np
df = pd.read_csv('boy.csv')
df.dropna(inplace = True)
df.head()
# Out:
# C:\Users\PC\AppData\Local\Temp\ipykernel_3088\4122922927.py:3: DtypeWarning: Columns (76) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('boy.csv')
# ...
